# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/INFO212/blob/main/INFO212_Assignment1_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Drexel University
# ## School of Computer and Information Sciences
# ## INFO 212: Data Science Programming I
# ## Assignment 1
# ### Due Date: Sunday, September 27, 2026
#
# # This notebook contains sample answers to the questions.

# %% [markdown]
# # Assignment 1: Find and Justify a Data Source
#
# ## What to do
#
# - Find sources of data on the web and show that it can actually be scraped.
#
# ## Why it matters
#
# - You will use the dataset for the rest of the assignments.
#
# ## What makes a good source
#
# - A good source has many similar items spread across several pages.
# - Think of a listing, a catalog, a directory, or a table of results.
# - Each item on the page becomes one row in your dataset.
# - Each piece of information about that item becomes one column.

# %% [markdown]
# ## Data Source Rules
#
# **Rule 1. The data must not already be packaged as a download**
#
# No Kaggle. No UCI repository. No `data.gov` CSV. No file that one click would fetch. You need to write a script in next assignment to fetch the data.
#
# **Rule 2. Size**
#
# The source must give you:
#
# - at least **100 rows**
# - at least **4 features**
# - with at least one **numeric** feature and at least one **text or categorical** feature

# %% [markdown]
# # Complete the Assignment by answering the following questions:

# %% [markdown]
# ### Question 1. Source Identification (5 points)

# %% [markdown]
# **What is the source called, and what is the URL to scrape?**
#
# *(your answer here)*
#
# The Wikipedia page for list of countries and dependencies by population
#
# https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population

# %% [markdown]
# ### Question 2. What the Data Is (5 points)
#
# **In two or three sentences, describe what this data is about. Write for a reader who has never seen the site. Use your own plain words. Do not copy the site's own description.**
#
# *(your answer here)*
#
# This Wikipedia page contains a list of countries and dependencies by population based on figures from official sources. If the numbers are not availble from the official sources, estimated numbers are presented from the United Nations.

# %% [markdown]
# ### Question 3. Features (5 points)
#
# List **at least 4 features** you expect to extract.
#
# For every feature give four things.
#
# - **Name.** What you will call it in your dataset.
# - **Meaning.** What it holds, in plain words.
# - **Expected type.** Number, text, category, or date.
# - **Real example value.** Copy an actual value off the page. Don't invent. The TA will ask it during the oral grading.
#
# At least one feature must be numeric. At least one must be text or categorical.
#
# Describe more if you have more than 6 features.

# %% [markdown]
# *(your answer here)*
# | Dataset feature | Meaning | Expected type | Actual example |
# |---|---|---|---|
# | `location` | Country or territory name | Text | `United States` |
# | `population` | Reported number of residents | Number | `341,784,857` |
# | `world_share_pct` | Percentage of the world’s population | Number | `4.1%` |
# | `reference_date` | Date the population figure refers to | Date | `1 Jul 2025` |
# | `source_type` | How the figure was obtained | Category | `Official estimate` |

# %% [markdown]
# ### Question 4. Feasibility (5 points)
#
# This question asks whether your source is actually big enough.
#
# **4a.** How many items are in the source?
#
# *(your answer here)*
#
# The table contains 195 countires.
#
#
# **4b.** How many rows do you expect in total?
#
# *(your answer here)*
#
# 195 rows.

# %% [markdown]
# ### Question 5. Ethics Check (5 points)
#
# **5a.** Open `https://<your-site>/robots.txt` in a browser. Is the content blocked?
#
#
# *(answer)*
#
# The full robots.txt is here: https://en.wikipedia.org/robots.txt
#
# The content is not blocked.
#
# The scrape path is /wiki/List_of_countries_and_dependencies_by_population . It is allowed to crawl.
#
#
# **5b.** Find the site's terms of use or terms of service. State whether they permit what you plan to do, and link to the page or quote the relevant sentence.
#
# *(answer)*
#
# The crawler should follow the usage policies and doesn't disrupt the site.
#
#
# **5c.** Confirm both of these in one sentence each.
#
# - Your data is not behind a login.
# - Your data contains no personal information about private individuals.
#
# *(answer)*
#
# If `robots.txt` disallows your path, or the terms forbid scraping, stop and pick another source.
#
# The data is not behind a login and the data contains no personal information about private individuals.

# %% [markdown]
# ### Question 6. Two Questions You Want to Answer (2 points)
#
# Name two questions you would want this data to answer by the end of the term.
#
# *(answer)*
#
# 1. What is the median population in the world and which countries have population close to the median?
#
# 2. What is the percentage of world population lives in countries in North America?

# %% [markdown]
# ### Question 7. AI Use Notes (3 points)
# - In 1-2 sentences, describe how you used AI in this assignment.
#
# *(Your AI Use Description Here)*:
#
# I used Chatgpt to help me locate websites that allow to scrape data I am interested and verify that I can scrape at least 100 rows and 4 features. I also used AI tools to locate and analyze robots.txt file so that the content is not blocked.

# %% [markdown]
# ---

# %% [markdown]
# ## DON'T CHANGE OR MODIFY THE FOLLOWING CONTENT
# - The following content is provided for your information only.
# - It describes the marking schemes for both written and oral parts.
# - Just read how the assignment will be graded. No questions to be answered.
# - The TA or the instructor will fill up the tables.

# %% [markdown]
# # Marking Scheme
#
# Your grade for this assignment is out of 100 points. **Most of it comes from the oral session.**
#
# | Part | Points |
# |---|---|
# | Written notebook | **30** |
# | Oral session with the TA | **70** |

# %% [markdown]
# ## Written notebook: 30 points (The table is filled up by the TA or instructor.)
#
# | Item | Points |
# |---|---|
# | Q1. Source identification, including the URL pattern for later pages |  |
# | Q2. What the data is, and what one row represents |  |
# | Q3. Features |  |
# | Q4. Feasibility |  |
# | Q5. Ethics check  |  |
# | Q6. Two specific questions |  |
# | Q7. AI Use Notes | |

# %% [markdown]
# ## Oral grading session: 70 points
#
# Sign up an oral grading session with the TA in week 2, with your source page open in a browser. The oral session aims to grade the assignment in three aspects: sense (30 points), size (20 points), features (20 points).
#
# ## The table is filled up by the TA or instructor.
#
# | Question | What it checks | Points |
# |---|---|---|
# | **Sense** | Does this dataset make sense? Do you know what one row is, and why this source is worth scraping? | |
# | **Size** | Is it big enough? Do you know how many rows there are, and is that a real count rather than a guess? | |
# | **Features** | Does it have the right columns? Do you know the types, and can you point at a real example value on the page? | |
