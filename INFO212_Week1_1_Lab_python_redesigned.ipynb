# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/INFO212/blob/main/INFO212_Week1_1_Lab_python_redesigned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## SCIS at Drexel University
#
# ## Week 1 - Lab 1: Introduction
#
# We will use a lot of tools in this course. This lab makes sure your environment works and that you can explain what your code is doing.
#
# ### How labs work
#
# To learn from the labs,  work through the following steps.
#
# 1. **What.** Write what is being asked and why it matters.
# 2. **Plan.** Write the steps in plain English. No Python in that cell.
# 3. **Code.** Develop the code.
# 4. **Verify.** Did the output match your prediction? If not, what was wrong?
#
# ### Which labs get submitted
#
# Labs belong to the course participation, quizzes, and labs part of your grade.
#
# Not every lab is collected. The instructor announces in class which labs are required. A required lab is submitted by the end of the lecture day. A lab that is not required is still practice worth finishing, and it is not graded.

# %% [markdown]
# ## Exercise 1: Build a small dataset
#
# **Task.** Create a CSV file with 3 attributes and at least 10 records. Save it as `mydata.csv`.
#
# - On your own machine, put the file in the same folder as this notebook.
# - Upload a copy to your Google Drive folder `info212`.
#
# Then print the absolute path of the file.

# %% [markdown]
# ### Step 1. What?
#
# - What is asked and why?
# - Where would a data scientist run into this problem in real work?
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 2. Plan
#
# No Python in this cell.
#
# - List your steps in order.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 3. Code
#
# Write the file and print its absolute path.

# %% [markdown]
# ### Step 4. Verify
#
# - Open `mydata.csv` in a plain text editor.
#
# ```
# paste the first three lines here
# ```
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### AI Log
#
# AI tools are allowed in this course. The rule is to use AI as a scaffold and not as the solution. Write the code yourself first, then ask the AI to find your bug.
#
# Fill this in honestly. Leave it empty if you did not use a tool.
#
# - **Prompt I used.**
# - **What it gave back (one or two lines).**
# - **What I changed and why.** If you changed nothing, say why the output was already right for this task.

# %% [markdown]
# ## Exercise 2: Read the file line by line
#
# **Task.** Write a program that opens `mydata.csv` and prints out the lines of the file.

# %% [markdown]
# ### Step 1. What?
#
# - What is asked and why?
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 2. Plan.
#
# - List your steps in order.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 3. Code

# %% [markdown]
# ### Step 4. Verify
#
# Print the lines of the file.

# %% [markdown]
# ### AI Log
#
# AI tools are allowed in this course. The rule is to use AI as a scaffold and not as the solution. Write the code yourself first, then ask the AI to find your bug.
#
# Fill this in honestly. Leave it empty if you did not use a tool.
#
# - **Prompt I used.**
# - **What it gave back (one or two lines).**
# - **What I changed and why.** If you changed nothing, say why the output was already right for this task.
