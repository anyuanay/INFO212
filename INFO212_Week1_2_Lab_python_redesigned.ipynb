# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/INFO212/blob/main/INFO212_Week1_2_Lab_python_redesigned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## SCIS at Drexel University
#
# ## Week 1 - Lab 2: Python
#
# Using Python to process strings.
#
# ### How labs work
#
# To learn from the labs,  work through the following steps.
#
# 1. **What.** Write what is being asked and why it matters.
# 2. **Plan.** Write the steps in plain English. No Python in that cell.
# 3. **Code.** Develop the code.
# 4. **Verify.** Did the output match your prediction? If not, what was wrong?
#
# ### Which labs get submitted
#
# Labs belong to the course participation, quizzes, and labs part of your grade.
#
# Not every lab is collected. The instructor announces in class which labs are required. A required lab is submitted by the end of the lecture day. A lab that is not required is still practice worth finishing, and it is not graded.

# %% [markdown]
# ## Exercise 1: Bigrams
#
# **Task.** Write a `for` loop that prints every pair of two consecutive characters (bigrams) in the string `"Hello World"`.

# %% [markdown]
# ### Step 1. What?
# - What is asked and why?
# - Bigrams show up in spell checkers, search engines, and text features for machine learning. Pick one of those and explain in two sentences why pairs of characters are useful there.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 2. Plan.
#
# - Write the steps in plain english describing how to solve it.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 3. Code

# %% [markdown]
# ### Step 4. Verify.
#
# - Did your printed count match the formula from Step 2?
# - If it did not, which end of the loop was wrong, the start or the stop? Explain what you had believed about `range`.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### AI Log
#
# AI tools are allowed in this course. The rule is to use AI as a scaffold and not as the solution. Write the code yourself first, then ask the AI to find your bug.
#
# Fill this in honestly. Leave it empty if you did not use a tool.
#
# - **Prompt I used.**
# - **What it gave back (one or two lines).**
# - **What I changed and why.** If you changed nothing, say why the output was already right for this task.

# %% [markdown]
# ## Exercise 2: Slicing a string
#
# **Task.** Given `s = "This sentence is false"`, pull out the substring `"sentence is"`. Print the individual characters, each on its own line.
#
# Shorter scaffold. Finish at home if lab time runs out.

# %% [markdown]
# ### Step 1. What?
#
# - What is asked and why?
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 2. Code
#
# Solve it twice. Once with a hard-coded slice, once using `find()`.

# %%
s = "This sentence is false"

# version 1: hard-coded slice

# %%
# version 2: using find()

# %% [markdown]
# ### Step 3. Verify
#
# - Did your two index numbers from Step 1 give the right substring on the first try? If not, which one was off and by how much?
# - Did the line count match your prediction?
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 4. Reflect
#
# - Why is the end index of a Python slice exclusive? Show one small example where that rule saves you arithmetic.
# - Change the sentence to `"That sentence is true"` and run both versions again. Which one still works? Say what that tells you about hard-coded numbers.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### AI Log
#
# AI tools are allowed in this course. The rule is to use AI as a scaffold and not as the solution. Write the code yourself first, then ask the AI to find your bug.
#
# Fill this in honestly. Leave it empty if you did not use a tool.
#
# - **Prompt I used.**
# - **What it gave back (one or two lines).**
# - **What I changed and why.** If you changed nothing, say why the output was already right for this task.
