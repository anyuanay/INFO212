# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/INFO212/blob/main/INFO212_Week2_Lab1_python_redesigned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## SCIS at Drexel University
#
# ## Week 2 - Lab 1: Python Data Structures
#
# Storing records with tuples and lists, then pulling pieces back out with indexing and slicing.
#
# ### How labs work
#
# To learn from the labs,  work through the following steps.
#
# 1. **What.** Write what is being asked and why it matters.
# 2. **Plan.** Write the steps in plain English. No Python in that cell.
# 3. **Code.** Develop the code.
# 4. **Verify.** Did the output match your prediction? If not, what was wrong?
#
# ### Which labs get submitted
#
# Labs belong to the course participation, quizzes, and labs part of your grade.
#
# Not every lab is collected. The instructor announces in class which labs are required. A required lab is submitted by the end of the lecture day. A lab that is not required is still practice worth finishing, and it is not graded.

# %% [markdown]
# ## Exercise 1: Student records
#
# **Task.** Create a tuple of several students. Each student is a list holding a name, a phone number, and an email. Print the information of each student on its own line.

# %% [markdown]
# ### Step 1. What?
#
# - What is asked and why?
# - A tuple of lists is one way to hold a small table of records. Where would a data scientist run into this shape in real work?
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 2. Plan
#
# No Python in this cell.
#
# - List your steps in order.
# - Say how many lines you expect to print.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 3. Code
#
# Build the tuple and print one student per line.

# %% [markdown]
# ### Step 4. Verify
#
# - How many lines did you print? Does that match the number of students you created?
# - Run the cell below. The first line changes a phone number inside a student. The second line replaces a whole student. One of them fails.
# - Which one failed, and what was the error? Explain what a tuple actually protects and what it does not.
#
# **Your answer.**
#
# _Type here before you run anything._

# %%
# students is your tuple from Step 3
students[0][1] = "555-0100"
print(students[0])

students[0] = ["New Name", "555-0199", "new@drexel.edu"]

# %% [markdown]
# ### AI Log
#
# AI tools are allowed in this course. The rule is to use AI as a scaffold and not as the solution. Write the code yourself first, then ask the AI to find your bug.
#
# Fill this in honestly. Leave it empty if you did not use a tool.
#
# - **Prompt I used.**
# - **What it gave back (one or two lines).**
# - **What I changed and why.** If you changed nothing, say why the output was already right for this task.

# %% [markdown]
# ## Exercise 2: Indexing and slicing a list
#
# **Task.** Given `s = [3, 5, 4, 2, 1, 9, 8, 0]`, do three things. Pull out the last four elements using positive indices. Pull out the last four elements using negative indices. Then pull out everything except the first and last element.
#
# Shorter scaffold. Finish at home if lab time runs out.

# %% [markdown]
# ### Step 1. What?
#
# - What is asked and why?
# - Before you write anything, write down the index numbers you expect each answer to start and stop at.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 2. Code
#
# Solve it three ways. Print each result.

# %%
s = [3, 5, 4, 2, 1, 9, 8, 0]

# version 1: last four elements, positive indices

# %%
# version 2: last four elements, negative indices

# %%
# version 3: everything except the first and last element

# %% [markdown]
# ### Step 3. Verify
#
# - Did each slice give the number of elements you predicted in Step 1? If one was off, which end was wrong, the start or the stop?
# - Which version needed `len(s)` and which one did not?
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### Step 4. Reflect
#
# - Change `s` to a list of six numbers and run all three cells again. Which versions still give the last four elements without any editing? Say what that tells you about typing index numbers by hand.
# - What does `s[1:-1]` return when `s` holds only one element? Predict first, then check.
#
# **Your answer.**
#
# _Type here before you run anything._

# %% [markdown]
# ### AI Log
#
# AI tools are allowed in this course. The rule is to use AI as a scaffold and not as the solution. Write the code yourself first, then ask the AI to find your bug.
#
# Fill this in honestly. Leave it empty if you did not use a tool.
#
# - **Prompt I used.**
# - **What it gave back (one or two lines).**
# - **What I changed and why.** If you changed nothing, say why the output was already right for this task.
